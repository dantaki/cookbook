# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True,
                          pfx=None):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title,fontsize=14)

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    
    
    nm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    nthresh = nm.max() / 1.5
    thresh=cm.max() / 2

    print(nthresh)
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{:0.4f}".format(nm[i, j]),
                     horizontalalignment="center",
                     color="white" if nm[i, j] > .97 else "black",fontsize=18)
        
        plt.text(j, i+0.1, "n={:,}".format(cm[i, j]),
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black",fontsize=14)


    plt.ylabel('True label',fontsize=14)
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass),fontsize=14)
    plt.tight_layout()
    plt.savefig("../FIGURES/png/{}.png".format(pfx))

# %%
dl = np.array([[194839,4926],[8156,145864]])
iv = np.array([[1581,1566],[386,92424]])
dp = np.array([[2517,395],[351,11912]])

plot_confusion_matrix(
    dl,
    normalize    = True,
    target_names = ['SV', 'Noise'],
    title        = "Split-Read Deletions",
    pfx          = "augr_del"
)

plot_confusion_matrix(
    dp,
    normalize    = True,
    target_names = ['SV', 'Noise'],
    title        = "Split-Read Duplications",
    pfx          = "augr_dup"
)

plot_confusion_matrix(
    iv,
    normalize    = True,
    target_names = ['SV', 'Noise'],
    title        = "Split-Read Inversion",
    pfx          = "augr_inv"
)
# Out:
# 0.6502273504701358
# 0.647584875913996
# 0.6638939769421398

# %%
dl = np.array([[51003,6569],[0,0]])
iv = np.array([[441,1982],[0,0]])
dp = np.array([[565,15152],[0,0]])

plot_confusion_matrix(
    dl,
    normalize    = True,
    target_names = ['SV', 'Noise'],
    title        = "Split-Read Deletions",
    pfx          = "augr_del_bsmn"
)

plot_confusion_matrix(
    dp,
    normalize    = True,
    target_names = ['SV', 'Noise'],
    title        = "Split-Read Duplications",
    pfx          = "augr_dup_bsmn"
)

plot_confusion_matrix(
    iv,
    normalize    = True,
    target_names = ['SV', 'Noise'],
    title        = "Split-Read Inversion",
    pfx          = "augr_inv_bsmn"
)
# Out:
# /home/dantakli/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: invalid value encountered in true_divide
# nan
# nan
# nan

# %%
for x in xb.columns: print(x)
# Out:
# set
# svtype
# cohort
# svlen
# tp
# fp
# fn
# tn
# fdr
# f1
# roc
# ap
# mcc
# clf
# seed
# max_depth
# eta
# gamma
# min_child_weight
# max_delta_step
# subsample
# sampling_method
# lambda
# alpha
# scale_pos_weight
# objective
# eval_metric

# %%
set(xb['max_depth'])
# Out:
# {2, 3, 5, 8, 13, 21, 34, 55, 89}
